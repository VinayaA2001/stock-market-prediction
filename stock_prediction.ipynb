# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Sample data
data = {
    'Day': list(range(1, 21)),
    'Price': [120, 122, 123, 125, 127, 130, 131, 133, 135, 136,
              138, 139, 140, 142, 145, 147, 149, 151, 152, 154]
}

df = pd.DataFrame(data)

# Features and target
X = df[['Day']]
y = df['Price']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R² Score:", r2)

# Plot
plt.scatter(X, y, color='blue', label='Actual Price')
plt.plot(X, model.predict(X), color='red', label='Predicted Line')
plt.title('Stock Price Prediction')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 0.1807443707725186
# R² Score: 0.9989472479314305

# %%
=
